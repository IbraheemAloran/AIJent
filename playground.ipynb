# %%
client = genai.Client()
response = client.models.generate_content(
    model="gemma-4-31b-it",
    contents=f"Parse this resume: {text}",
    config={
        "response_format": {"text": {"mime_type": "application/json", "schema": Profile.model_json_schema()}},
    },
)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2")

# %%
vectors = embeddings.embed_documents(jobs)

# %%
vector = embeddings.embed_query("SUMMARY: Machine Learning Engineer with 2+ years of experience building and deploying scalable AI/ML systems across NLP, Generative AI, RAG, and Time-Series Forecasting using Python, PyTorch, and MLOps tools on GCP and AWS with a strong research background. Experienced in collaborating with cross-functional teams to deliver production-ready ML solutions. EXPERIENCE: Collaborated with stakeholders and engineers to research and design a novel multi-lingual text-to-speech model for a video auto-dubbing service, building scalable pipelines with Docker, Kubeflow, and Google Cloud Platform (GCP). Built an audio codec quantization model with GAN-based training in PyTorch for high-quality speech synthesis and voice cloning, achieving 90% speaker similarity and improving model performance by 20% through balanced batch sampling. Implemented distributed multi-GPU training and integrated the Vocos decoder, reducing training time by 40% and inference time by 30%, saving $108,000 annually in compute costs. Built an audio preprocessing pipeline for normalization, resampling, and dynamic padding for model training. Led the deployment of scalable ML systems to production on GCP using microservices and REST APIs with FastAPI, integrating MLflow and Vertex AI for experiment tracking and model lifecycle management, following Agile/Scrum practices. Built an end-to-end RAG pipeline for a medical research chatbot, processing and chunking PDF research papers into a Pinecone vector store using HuggingFace embeddings and GPT for response generation. Implemented hybrid retrieval combining dense vector search and BM25 sparse encoding, improving answer relevance by 30% over single-method retrieval across a corpus of medical literature. Integrated conversational memory into the RAG architecture to preserve multi-turn context, reducing redundant queries by 40% and improving response coherence across complex medical Q&A sessions. Facilitated lab sessions for 30+ students on data structures and algorithms, including graphing and sorting, in C and Java. Collaborated with a cross-functional team to develop UNI, a management platform used to share and facilitate content. Developed a product key system in Java to authorize valid devices and prevent software piracy, and built REST APIs using TypeScript and Node.js to alleviate server bottlenecks and reduce traffic by 30%, contributing to a 10% increase in clients. PROJECTS: Built an end-to-end RAG system with integrated memory and BGE-based reranking, improving NDCG@10 by 25% to process customer claims and generate actionable resolutions. Implemented a hybrid search pipeline using vector similarity and BM25 encoder, with Dockerized deployment and FastAPI REST endpoints for seamless integration to production. Built an end-to-end AI meeting assistant enabling transcription, summarization, and Q&A over long meeting audio. Fine-tuned Whisper ASR with QLoRA, achieving 9% word error rate, and built a hybrid RAG pipeline with a BM25 encoder using Gemma LLM to generate format-specific meeting summaries and context-aware answers.")
vector
# Out:
# [-0.007814147509634495,
#  0.02549721859395504,
#  -0.0043020593002438545,
#  0.011266822926700115,
#  0.001143120345659554,
#  -0.015963206067681313,
#  -0.03227506950497627,
#  0.015406538732349873,
#  0.0025270762853324413,
#  -0.06958171725273132,
#  -0.020506111904978752,
#  0.020415358245372772,
#  0.020961003378033638,
#  -0.0038690173532813787,
#  -0.019910428673028946,
#  -0.008879004046320915,
#  0.03880875185132027,
#  -0.029219722375273705,
#  -0.03695683926343918,
#  -0.0024977687280625105,
#  -0.004056018311530352,
#  -0.013247891329228878,
#  -0.004899142310023308,
#  -0.006207820028066635,
#  -0.010173830203711987,
#  0.004486911464482546,
#  0.00273493560962379,
#  0.0025589680299162865,
#  0.008115094155073166,
#  -0.00675479881465435,
#  -0.014398548752069473,
#  0.0074002668261528015,
#  -0.007540104445070028,
#  -0.0023387782275676727,
#  0.026833564043045044,
#  -0.009674726985394955,
#  -0.0065346346236765385,
#  0.0006943349144421518,
#  0.0038608447648584843,
#  0.003638663562014699,
#  0.006362355314195156,
#  -0.01691780425608158,
#  -0.0014074372593313456,
#  -0.028136728331446648,
#  -0.0004219440743327141,
#  0.011879388242959976,
#  -0.008190194144845009,
#  -0.010121145285665989,
#  -0.002129791770130396,
#  0.0054863435216248035,
#  0.004978362936526537,
#  -1.8912614905275404e-05,
#  0.022770211100578308,
#  0.0015839996049180627,
#  0.025382302701473236,
#  0.007414443884044886,
#  -0.0178582314401865,
#  -0.016737891361117363,
#  -0.009522409178316593,
#  -0.0052875373512506485,
#  -0.1166791096329689,
#  0.015920467674732208,
#  -0.00015728552534710616,
#  0.018270710483193398,
#  0.00530007341876626,
#  -0.023891260847449303,
#  -0.0041703530587255955,
#  -0.020752601325511932,
#  0.01330440305173397,
#  -0.009330892004072666,
#  -0.008237408474087715,
#  0.0023025667760521173,
#  0.013210449367761612,
#  -0.010188189335167408,
#  0.003924217075109482,
#  -0.047882694751024246,
#  0.004143580794334412,
#  0.005297372583299875,
#  0.004066346678882837,
#  0.014296004548668861,
#  -0.015833551064133644,
#  -0.0062296511605381966,
#  0.0001247365289600566,
#  -0.0016385962953791022,
#  0.0001625308650545776,
#  -0.00458518136292696,
#  -0.0024364041164517403,
#  -0.002188275568187237,
#  0.0024032292421907187,
#  -0.003561119083315134,
#  0.01339051779359579,
#  -0.002168874489143491,
#  -0.03347330167889595,
#  0.008377139456570148,
#  -0.0060495841316878796,
#  0.005402520298957825,
#  0.0018149405950680375,
#  -0.010508660227060318,
#  0.011591249145567417,
#  -0.008434695191681385,
#  0.021604496985673904,
#  -0.025372760370373726,
#  0.004273210186511278,
#  -0.019518937915563583,
#  -0.011793175712227821,
#  0.014954648911952972,
#  -0.002888098359107971,
#  0.025064459070563316,
#  -0.05808911845088005,
#  0.010041383095085621,
#  -0.00199635187163949,
#  -0.0008240804309025407,
#  -0.012161229737102985,
#  -0.015667302533984184,
#  -0.01418303232640028,
#  0.0002901802654378116,
#  0.006100681610405445,
#  0.0076293619349598885,
#  0.014526259154081345,
#  0.007907622493803501,
#  0.11516903340816498,
#  0.01196751557290554,
#  -0.024697594344615936,
#  0.040108419954776764,
#  0.009419268928468227,
#  -0.0016097481129691005,
#  0.016140218824148178,
#  -0.0129229836165905,
#  -0.012750620022416115,
#  0.008663199841976166,
#  0.020921949297189713,
#  -0.002147868974134326,
#  0.002797923982143402,
#  0.0009985625511035323,
#  0.003849745960906148,
#  0.00978003442287445,
#  -0.011266873218119144,
#  ...]

# %%
len(vector)
# Out:
# 3072

# %%
llm = ChatOllama(model="gemma4:31b-cloud", format="json")
structured_llm = llm.with_structured_output(Profile)
# agent = create_agent(
#     model=llm,
#     system_prompt="You are a resume parser agent that takes resume text and extracts all information and outputs it to the proper fields",
#     response_format= Profile
# )

# %%
response = structured_llm.invoke(f"Parse this resume: {text}")

# %%
response

# %%
from parser_mcp_server import ResumeParser
# Out:
# i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
rp = ResumeParser()

rp.parse()

# %%
import json
with open("profile.json", "r") as f:
    data = json.load(f)

# print(data)
print(data["all_bullet_points_and_summary"])
# Out:
# SUMMARY: Machine Learning Engineer with 2+ years of experience building and deploying scalable AI/ML systems across NLP, Generative AI, RAG, and Time-Series Forecasting using Python, PyTorch, and MLOps tools on GCP and AWS with a strong research background. Experienced in collaborating with cross-functional teams to deliver production-ready ML solutions. EXPERIENCE: Collaborated with stakeholders and engineers to research and design a novel multi-lingual text-to-speech model for a video auto-dubbing service, building scalable pipelines with Docker, Kubeflow, and Google Cloud Platform (GCP). Built an audio codec quantization model with GAN-based training in PyTorch for high-quality speech synthesis and voice cloning, achieving 90% speaker similarity and improving model performance by 20% through balanced batch sampling. Implemented distributed multi-GPU training and integrated the Vocos decoder, reducing training time by 40% and inference time by 30%, saving $108,000 annually in compute costs. Built an audio preprocessing pipeline for normalization, resampling, and dynamic padding for model training. Led the deployment of scalable ML systems to production on GCP using microservices and REST APIs with FastAPI, integrating MLflow and Vertex AI for experiment tracking and model lifecycle management, following Agile/Scrum practices. Built an end-to-end RAG pipeline for a medical research chatbot, processing and chunking PDF research papers into a Pinecone vector store using HuggingFace embeddings and GPT for response generation. Implemented hybrid retrieval combining dense vector search and BM25 sparse encoding, improving answer relevance by 30% over single-method retrieval across a corpus of medical literature. Integrated conversational memory into the RAG architecture to preserve multi-turn context, reducing redundant queries by 40% and improving response coherence across complex medical Q&A sessions. Facilitated lab sessions for 30+ students on data structures and algorithms, including graphing and sorting, in C and Java. Collaborated with a cross-functional team to develop UNI, a management platform used to share and facilitate content. Developed a product key system in Java to authorize valid devices and prevent software piracy, and built REST APIs using TypeScript and Node.js to alleviate server bottlenecks and reduce traffic by 30%, contributing to a 10% increase in clients. PROJECTS: Built an end-to-end RAG system with integrated memory and BGE-based reranking, improving NDCG@10 by 25% to process customer claims and generate actionable resolutions. Implemented a hybrid search pipeline using vector similarity and BM25 encoder, with Dockerized deployment and FastAPI REST endpoints for seamless integration to production. Built an end-to-end AI meeting assistant enabling transcription, summarization, and Q&A over long meeting audio. Fine-tuned Whisper ASR with QLoRA, achieving 9% word error rate, and built a hybrid RAG pipeline with a BM25 encoder using Gemma LLM to generate format-specific meeting summaries and context-aware answers.

# %%
jobs = [""" Machine Learning Engineer

We are looking for a Machine Learning Engineer to design, build, and deploy scalable ML models in production.

Responsibilities:
- Develop and optimize deep learning models for NLP and recommendation systems
- Work with large-scale datasets using Python, PyTorch, and TensorFlow
- Deploy models using Docker and cloud platforms (AWS/GCP)
- Collaborate with data engineers and backend teams

Requirements:
- MSc or BSc in Computer Science or related field
- Strong Python programming skills
- Experience with PyTorch or TensorFlow
- Knowledge of NLP, embeddings, and transformers""",
""" Data Scientist

We are hiring a Data Scientist to analyze large datasets and build predictive models to drive business insights.

Responsibilities:
- Build and evaluate statistical and machine learning models
- Perform data cleaning, feature engineering, and visualization
- Work with SQL databases and large-scale data pipelines
- Communicate insights to stakeholders

Requirements:
- Strong foundation in statistics and probability
- Experience with Python (Pandas, NumPy, Scikit-learn)
- Experience with data visualization tools (Matplotlib, Seaborn)
- Knowledge of machine learning techniques such as regression and classification""",

""" Backend Software Engineer

We are seeking a Backend Software Engineer to design and build scalable APIs and distributed systems.

Responsibilities:
- Design RESTful APIs and microservices
- Build scalable backend systems using Python (FastAPI/Django) or Node.js
- Work with databases such as PostgreSQL and Redis
- Ensure system performance, reliability, and security

Requirements:
- Strong backend development experience
- Knowledge of system design and distributed systems
- Experience with cloud platforms (AWS, GCP, or Azure)
- Familiarity with Docker and CI/CD pipelines"""]

# %%
jobs[1]
# Out:
# ' Data Scientist\n\nWe are hiring a Data Scientist to analyze large datasets and build predictive models to drive business insights.\n\nResponsibilities:\n- Build and evaluate statistical and machine learning models\n- Perform data cleaning, feature engineering, and visualization\n- Work with SQL databases and large-scale data pipelines\n- Communicate insights to stakeholders\n\nRequirements:\n- Strong foundation in statistics and probability\n- Experience with Python (Pandas, NumPy, Scikit-learn)\n- Experience with data visualization tools (Matplotlib, Seaborn)\n- Knowledge of machine learning techniques such as regression and classification'

# %%
import Embedder.embedding_mcp_server as em
for j in jobs:
    print(em.similarity_score.invoke({"job": j}))
# Out:
# True
# False
# False

# %%
from dotenv import load_dotenv
from browser_use import Agent, ChatBrowserUse
load_dotenv()

llm = ChatBrowserUse(
    model='browser-use/bu-30b-a3b-preview',  # BU Open Source Model!!
)

agent = Agent(
    task='Find the number of stars of browser-use and stagehand. Tell me which one has more stars :)',
    llm=llm,
    flash_mode=True
)
agent.run_sync()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from browser_use import Agent, ChatBrowserUse
#       3 load_dotenv()
#       4
#       5 llm = ChatBrowserUse(
#
# ImportError: cannot import name 'ChatBrowserUse' from 'browser_use' (i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\browser_use\__init__.py)

# %%
from dotenv import load_dotenv
from browser_use import Agent, C
load_dotenv()
# Out:
# True

# %%
import asyncio
from browser_use_sdk.v3 import AsyncBrowserUse

async def main():
    client = AsyncBrowserUse()
    result = await client.run("List the top 20 posts on Hacker News today with their points")
    print(result.output)

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 9
#       5     client = AsyncBrowserUse()
#       6     result = await client.run("List the top 20 posts on Hacker News today with their points")
#       7     print(result.output)
#       8
# ----> 9 asyncio.run(main())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
agent = Agent(
    task='Find the number of stars of browser-use and stagehand. Tell me which one has more stars :)',
    llm=model,
)
agent.run_sync()
# Out:
# INFO     [browser_use.telemetry.service] Anonymized telemetry enabled. See https://docs.browser-use.com/development/telemetry for more information.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 agent = Agent(
#       2     task='Find the number of stars of browser-use and stagehand. Tell me which one has more stars :)',
#       3     llm=model,
#       4 )
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\browser_use\utils.py:330, in time_execution_sync.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     327 @wraps(func)
#     328 def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
#     329 	start_time = time.time()
# --> 330 	result = func(*args, **kwargs)
#     331 	execution_time = time.time() - start_time
#     332 	# Only log if execution takes more than 0.25 seconds
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\browser_use\agent\service.py:265, in Agent.__init__(self, task, llm, page, browser, browser_context, browser_profile, browser_session, controller, sensitive_data, initial_actions, register_new_step_callback, register_done_callback, register_external_agent_status_raise_error_callback, output_model_schema, use_vision, use_vision_for_planner, save_conversation_path, save_conversation_path_encoding, max_failures, retry_delay, override_system_message, extend_system_message, validate_output, message_context, generate_gif, available_file_paths, include_attributes, max_actions_per_step, use_thinking, flash_mode, max_history_items, images_per_step, page_extraction_llm, planner_llm, planner_interval, is_planner_reasoning, extend_planner_system_message, injected_agent_state, context, source, file_system_path, task_id, cloud_sync, calculate_cost, display_files_in_done_text, include_tool_call_examples, **kwargs)
#     263 # Token cost service
#     264 self.token_cost_service = TokenCost(include_cost=calculate_cost)
# --> 265 self.token_cost_service.register_llm(llm)
#     266 self.token_cost_service.register_llm(page_extraction_llm)
#     267 # Note: No longer registering planner_llm (deprecated)
#     268
#     269 # Initialize state
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\browser_use\tokens\service.py:344, in TokenCost.register_llm(self, llm)
#     340 	return result
#     342 # Replace the method with our tracked version
#     343 # Using setattr to avoid type checking issues with overloaded methods
# --> 344 setattr(llm, 'ainvoke', tracked_ainvoke)
#     346 return llm
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\pydantic\main.py:1048, in BaseModel.__setattr__(self, name, value)
#    1046     setattr_handler(self, name, value)
#    1047 # if None is returned from _setattr_handler, the attribute was set directly
# -> 1048 elif (setattr_handler := self._setattr_handler(name, value)) is not None:
#    1049     setattr_handler(self, name, value)  # call here to not memo on possibly unknown fields
#    1050     self.__pydantic_setattr_handlers__[name] = setattr_handler
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\pydantic\main.py:1095, in BaseModel._setattr_handler(self, name, value)
#    1092 elif name not in cls.__pydantic_fields__:
#    1093     if cls.model_config.get('extra') != 'allow':
#    1094         # TODO - matching error
# -> 1095         raise ValueError(f'"{cls.__name__}" object has no field "{name}"')
#    1096     elif attr is None:
#    1097         # attribute does not exist, so put it in extra
#    1098         self.__pydantic_extra__[name] = value
#
# ValueError: "ChatGoogleGenerativeAI" object has no field "ainvoke"

# %%
model.invoke("Hello")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model.invoke("Hello")
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2138, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2135         msg = "Tools are already defined.code_execution tool can't be defined"
#    2136         raise ValueError(msg)
# -> 2138 return super().invoke(input, config, stop=stop, **kwargs)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:472, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     458 @override
#     459 def invoke(
#     460     self,
#    (...)    465     **kwargs: Any,
#     466 ) -> AIMessage:
#     467     config = ensure_config(config)
#     468     return cast(
#     469         "AIMessage",
#     470         cast(
#     471             "ChatGeneration",
# --> 472             self.generate_prompt(
#     473                 [self._convert_input(input)],
#     474                 stop=stop,
#     475                 callbacks=config.get("callbacks"),
#     476                 tags=config.get("tags"),
#     477                 metadata=config.get("metadata"),
#     478                 run_name=config.get("run_name"),
#     479                 run_id=config.pop("run_id", None),
#     480                 **kwargs,
#     481             ).generations[0][0],
#     482         ).message,
#     483     )
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1752, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1743 @override
#    1744 def generate_prompt(
#    1745     self,
#    (...)   1749     **kwargs: Any,
#    1750 ) -> LLMResult:
#    1751     prompt_messages = [p.to_messages() for p in prompts]
# -> 1752     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1559, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1556 for i, m in enumerate(input_messages):
#    1557     try:
#    1558         results.append(
# -> 1559             self._generate_with_cache(
#    1560                 m,
#    1561                 stop=stop,
#    1562                 run_manager=run_managers[i] if run_managers else None,
#    1563                 **kwargs,
#    1564             )
#    1565         )
#    1566     except BaseException as e:
#    1567         if run_managers:
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1899, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1897     result = generate_from_stream(iter(chunks))
#    1898 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1899     result = self._generate(
#    1900         messages, stop=stop, run_manager=run_manager, **kwargs
#    1901     )
#    1902 else:
#    1903     result = self._generate(messages, stop=stop, **kwargs)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2295, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2293 if "max_retries" not in kwargs:
#    2294     kwargs["max_retries"] = self.max_retries
# -> 2295 response: GenerateContentResponse = _chat_with_retry(
#    2296     request=request,
#    2297     **kwargs,
#    2298     generation_method=self.client.generate_content,
#    2299     metadata=self.default_metadata,
#    2300 )
#    2301 return _response_to_result(response)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:269, in _chat_with_retry(generation_method, **kwargs)
#     264         raise
#     266 params = {
#     267     k: v for k, v in kwargs.items() if k in _allowed_params_prediction_service
#     268 }
# --> 269 return _chat_with_retry(**params)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\tenacity\__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:243, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     240 @retry_decorator
#     241 def _chat_with_retry(**kwargs: Any) -> Any:
#     242     try:
# --> 243         return generation_method(**kwargs)
#     244     except FailedPrecondition as exc:
#     245         if "location is not supported" in exc.message:
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:889, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     886 self._validate_universe_domain()
#     888 # Send the request.
# --> 889 response = rpc(
#     890     request,
#     891     retry=retry,
#     892     timeout=timeout,
#     893     metadata=metadata,
#     894 )
#     896 # Done; return the response.
#     897 return response
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\api_core\gapic_v1\method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     125 if self._compression is not None:
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      52 @functools.wraps(callable_)
#      53 def error_remapped_callable(*args, **kwargs):
#      54     try:
# ---> 55         return callable_(*args, **kwargs)
#      56     except grpc.RpcError as exc:
#      57         raise exceptions.from_grpc_error(exc) from exc
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\grpc\_interceptor.py:328, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     325     except Exception as exception:  # pylint:disable=broad-except
#     326         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
#     331 return call.result(), call
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:78, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 78 response = continuation(client_call_details, request)
#      79 if logging_enabled:  # pragma: NO COVER
#      80     response_metadata = response.trailing_metadata()
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     305 (
#     306     new_method,
#     307     new_timeout,
#    (...)    311     new_compression,
#     312 ) = _unwrap_client_call_details(new_details, client_call_details)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#     323 except grpc.RpcError as rpc_error:
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\grpc\_channel.py:1170, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def with_call(
#    1162     self,
#    1163     request: Any,
#    (...)   1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Tuple[Any, grpc.Call]:
# -> 1170     state, call = self._blocking(
#    1171         request, timeout, metadata, credentials, wait_for_ready, compression
#    1172     )
#    1173     return _end_unary_response_blocking(state, call, True, None)
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\grpc\_channel.py:1143, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1126 state.target = _common.decode(self._target)
#    1127 call = self._channel.segregated_call(
#    1128     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1129     self._method,
#    (...)   1141     self._registered_call_handle,
#    1142 )
# -> 1143 event = call.next_event()
#    1144 _handle_event(event, state, self._response_deserializer)
#    1145 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
# --> 388 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
# --> 211 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
# --> 205 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
# ---> 97 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
# ---> 80 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
# ---> 61 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
from hiring_cafe_scraper import scrape

jobs = scrape("machine learning engineer", 10, False)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[7], line 3
#       1 from hiring_cafe_scraper import scrape
#       2
# ----> 3 jobs = scrape("machine learning engineer", 10, False)
#
# File i:\Projects\AIJent\AIJent\hiring_cafe_scraper.py:77, in scrape(query, max_jobs, headless)
#      74 jobs: list[dict] = []
#      75 seen: set[str] = set()
# ---> 77 with sync_playwright() as p:
#      78     browser = p.chromium.launch(headless=headless)
#      79     ctx = browser.new_context(
#      80         user_agent=("Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7) "
#      81                     "AppleWebKit/537.36 (KHTML, like Gecko) "
#      82                     "Chrome/124.0 Safari/537.36"),
#      83         viewport={"width": 1400, "height": 1000},
#      84     )
#
# File i:\Projects\AIJent\AIJent\.venv\Lib\site-packages\playwright\sync_api\_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
#      53         # until the end of times. We will pass control to that fiber every time we
#      54         # block while waiting for a response.
#      55         def greenlet_main() -> None:
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.

# %%
import asyncio
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

# %%
async def use_browser_mcp():
    # Connect to browser-use MCP server
    server_params = StdioServerParameters(
        command="uvx",
        args=["--from", "browser-use[cli]", "browser-use", "--mcp"]
    )

    async with stdio_client(server_params) as (read, write):
        async with ClientSession(read, write) as session:
            await session.initialize()

            # Navigate to a website
            result = await session.call_tool(
                "browser_navigate",
                arguments={"url": "https://hiring.cafe/"}
            )
            print(result.content[0].text)

            # Get page state
            result = await session.call_tool(
                "browser_get_state",
                arguments={"include_screenshot": True}
            )
            print("Page state retrieved!")

# %%
asyncio.run(use_browser_mcp()
# Out:
# <coroutine object use_browser_mcp at 0x0000022B9B283CD0>

# %%
import sqlite3

with sqlite3.connect("profiles.db") as conn:

    cursor = conn.cursor()

    cursor.execute("""
    CREATE TABLE IF NOT EXISTS Profile (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        email TEXT,
        preferred_role TEXT
    )
    """)

    conn.commit()

# %%
query = "I am looking for a machine learning engineer role focused on NLP, LLMs, and distributed training systems."
db = ["We are hiring a machine learning engineer to work on large language models, NLP pipelines, and distributed GPU training infrastructure.", "The company is seeking a data scientist with experience in deep learning, Python, and cloud-based AI systems.", "This backend software engineer role involves building scalable APIs, microservices, and cloud infrastructure.", "We are hiring a business analyst to create reports, dashboards, and performance metrics for stakeholders."]

# %%
import Embedder.embedding_mcp_server as emb

emb.similarity_score(db)
# Out:
# [0.7351780685358068, 0.6628058731561773, 0.6030685003423065, 0.575808318439134]

# %%
a = [{a: 3},
     {b: 4},
     {c: 7}]


b = [23,35,78]


result = {{a: 3,
           n: 23},
            {b: 4,
            n: 35},
            {c: 7,
            n: 78}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a = [{a: 3},
#       2      {b: 4},
#       3      {c: 7}]
#       4
#
# NameError: name 'a' is not defined

# %%
d = {"a": 3}

new_dict = {**d, "n": 23}

print(new_dict)
# Out:
# {'a': 3, 'n': 23}
